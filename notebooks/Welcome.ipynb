// %% [markdown]
// # Welcome to OpenTSx Onboarding!
//
// This notebook environment is your "Lab" for exploring Time Series Analysis with OpenTSx.
//
// ## Environment Status
// If you are seeing this, your **Jupyter Lab** is working correctly!
//
// The following services should be available to you:
//
// - **Kafka**: `kafka:9092`
// - **Schema Registry**: `schema-registry:8081`
// - **OpenTSDB**: `opentsdb:4242`
// - **Flink**: `jobmanager:8081` (UI at http://localhost:8082)
// - **HBase**: `hbase:16000`
//
// ## Getting Started
//
// ### Scala/Spark Check
// Run the cell below to verify that Spark is ready.

// %%
import org.apache.spark.sql.SparkSession

val spark = SparkSession.builder()
    .appName("OpenTSx Onboarding")
    .master("local[*]")
    .getOrCreate()

println(s"Spark Version: ${spark.version}")

// %% [markdown]
// ## Next Steps
// Open the **Onboarding Tracks** documentation and start your journey!
//
// - [Flink Track]
// - [Software Engineer Track]
// - [Time Series Expert Track]
